# %%
import tweepy
import pandas as pd
import numpy as np
import re
import csv
import string

# %%
api_key = "TCPfuZbCcqQxwnOkIS8pY58dR"
api_secret_key = "amknSLzf82Qr2HFHQ7Ojxf9cEpYwcleCpSXgVUPMV8LflHyRZL"
access_token = "1590922003518656513-PzhUXkIFueBAPFDm3IG7rtaJMyOmkW"
access_token_secret = "9U9BOiXBS41ZYLTljX9bWZysCcVute3aYHTTBpr8T6vqD"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
search_key = "karen's diner"

csvfile = open(search_key+".csv", "a+", newline="", encoding="utf-8")
csvwriter = csv.writer(csvfile)
u = []
t = []

for tweet in tweepy.Cursor(api.search, q = search_key, count =1000, lang="id").items(1000):
  # print(tweet.user.name, tweet.text)
  u.append(tweet.user.name)
  t.append(tweet.text.encode("utf-8"))
  tweets = [tweet.user.name, tweet.text.encode("utf-8")]
  csvwriter.writerow(tweets)

dictTweets = {"username":u, "teks":t}
df = pd.DataFrame(dictTweets, columns = ["username", "teks"])

df
# Out:
#                    username                                               teks
# 0                       sal  b'RT @asonofapeach: Karen\xe2\x80\x99s Diner? ...
# 1              Nazwa soraya  b"RT @handokotjung: *Anak dari keluarga tidak ...
# 2            Anggirengganis  b'Mau reschedule tgl reservasi for karen\xe2\x...
# 3      Farchan Noor Rachman  b'RT @KrisnaERLG: Ini baru Karen\xe2\x80\x99s ...
# 4                md jackson  b'RT @asonofapeach: Karen\xe2\x80\x99s Diner? ...
# ..                      ...                                                ...
# 995    hourly nightblogging  b"RT @natanattda: ini baru karen's diner https...
# 996          Intan Paramita  b"RT @ikanatassa: orang medan masuk karen's di...
# 997                      Mi  b"RT @newsplatter: Bawa Filosofi Teras terus m...
# 998  waiting byun baekhyun🐿  b'RT @skijiegff: \xf0\x9f\x8c\xb7rekomendasi t...
# 999                      na  b"RT @handokotjung: *Anak dari keluarga tidak ...
#
# [1000 rows x 2 columns]

# %%
df = df.drop_duplicates(subset= 'teks', keep='first', inplace=False)
df
# Out:
#                             username  \
# 0                                sal
# 1                       Nazwa soraya
# 2                     Anggirengganis
# 3               Farchan Noor Rachman
# 5                    Krisna Erlangga
# ..                               ...
# 965                             Aree
# 970                       уαиα нαυ∂у
# 974  Hype | Influencer Marketing App
# 978                    ฅ⁠^⁠•⁠ﻌ⁠•⁠^⁠ฅ
# 983                       muja hidin
#
#                                                   teks
# 0    b'RT @asonofapeach: Karen\xe2\x80\x99s Diner? ...
# 1    b"RT @handokotjung: *Anak dari keluarga tidak ...
# 2    b'Mau reschedule tgl reservasi for karen\xe2\x...
# 3    b'RT @KrisnaERLG: Ini baru Karen\xe2\x80\x99s ...
# 5    b'Ini baru Karen\xe2\x80\x99s Diner. https://t...
# ..                                                 ...
# 965  b'BENER-BENER GA PERLU KE KAREN\xe2\x80\x99S D...
# 970  b"Waiter and waitress Karen's Diner apa ga cpt...
# ...

# %%
def cleanTxt(text):
  text = re.sub(r'@[A-Za-z0-9]+','',text) #Remove @mentions
  text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text) #Remove http links
  text = re.sub(r'#', '', text) #Removing the '#' simbol
  text = re.sub(r'RT[\s]+', '', text) #Removing RT
  text = re.sub(r'https?:\/\/S+', '', text) #Remove the hyperlink
  text = re.sub(r'[^\w]|_',' ',text) #remove punctuations
  text = re.sub(r'b[\s]+', '', text) #Removing RT

  return text

#Cleaning the text

df['teks'] = df['teks'].apply(cleanTxt)

#Show the cleaned text
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b2e46e138625> in <module>
#      12 #Cleaning the text
#      13
# ---> 14 df['teks'] = df['teks'].apply(cleanTxt)
#      15
#      16 #Show the cleaned text
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
from google.colab import files
df.to_csv('dataset.csv', encoding = 'utf-8-sig') 
files.download('dataset.csv')
